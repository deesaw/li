# %%
import win32com.client
import datetime as dt
import pandas as pd
import xlrd
import glob
import os
import win32com.client
import datetime as dt


myFiles = glob.glob('*.xlsx')
print(myFiles)
for file in myFiles:
    print(file)
    df=pd.read_excel(file,header=0,dtype=object)
# Out:
# ['ML_TRAINING_DATA_ALL.xlsx']
# ML_TRAINING_DATA_ALL.xlsx

# %%
outlook = win32com.client.Dispatch('Outlook.Application').GetNamespace('MAPI')
namespace = outlook.Session
recipient = namespace.CreateRecipient("deesaw@deloitte.com")
inbox = outlook.GetDefaultFolder(6)#(recipient, 6)
messages = inbox.Items
email_subject = []
i=0
for x in messages:
    i=i+1
    sub = x.Subject
    email_subject.append(sub)
    if i >21000:
        break

# %%
df1=pd.DataFrame()
for d in df['UID']:
    df1['UID']=d
    for e in email_subject:
        if str(d) in e:
            df1['Subject']=e
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-1177611b4962> in <module>
#       1 df1=pd.DataFrame()
# ----> 2 for d in df['UID']:
#       3     df1['UID']=d
#       4     for e in email_subject:
#       5         if str(d) in e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UID'

# %%
df
# Out:
#       Unnamed: 0 Unnamed: 1                              Unnamed: 2  \
# 0            NaN        NaN                                     NaN
# 1            NaN        NaN                                  Values
# 2          Payer   D/C Ind.  Min of Percent of Pay Amt / Inv. Amt.
# 3              *          S                                 5.09762
# 4       10000100          S                                 96.0417
# ..           ...        ...                                     ...
# 576       301136          S                                 2692.05
# 577     70000000          S                                      50
# 578     70000010          S                                 2.29885
# 579      (blank)    (blank)                                     NaN
# 580  Grand Total        NaN                                       0
#
#                                  Unnamed: 3  \
# 0                                       NaN
# 1                                       NaN
# 2    Max of Percent of Pay Amt / Inv. Amt.
# 3                                   54987.3
# 4                                        98
# ..                                      ...
# 576                                  506700
# 577                                 109.928
# 578                                 100.075
# 579                                     NaN
# 580                             8.92145e+07
#
#                                      Unnamed: 4  \
# 0                                           NaN
# 1                                           NaN
# 2    Average of Percent of Pay Amt / Inv. Amt.
# 3                                       506.489
# 4                                       97.0208
# ..                                          ...
# 576                                     98644.8
# 577                                     99.7928
# 578                                     94.7743
# 579                                         NaN
# 580                                     29163.8
#
#                                      Unnamed: 5
# 0                                           NaN
# 1                                           NaN
# 2    StdDevp of Percent of Pay Amt / Inv. Amt.
# 3                                        4724.1
# 4                                      0.979167
# ..                                          ...
# 576                                     80526.9
# 577                                       4.046
# 578                                     21.4508
# 579                                         NaN
# 580                                      541784
#
# [581 rows x 6 columns]
